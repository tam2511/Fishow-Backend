# %%
import pandas as pd
from IPython.display import clear_output
from random import choice, randint
from prettytable import PrettyTable

# %%
fishs = ['щука', 'судак', 'окунь', 'берш', 'речная форель', 'озерная форель', 'елец', 'чехонь', 'сом', 'голавль', 'язь',
         'карп', 'жерех', 'лещ', 'карась', 'линь', 'пескарь', 'ротан', 'плотва', 'красноперка', 'налим', 'густера',
         'амур', 'ерш', 'сазан', 'подуст', 'толстолобик', 'вобла', 'хариус']
fishs_bel = ['елец', 'чехонь', 'сом', 'голавль', 'язь', 'карп', 'жерех', 'лещ', 'карась', 'линь', 'пескарь', 'плотва', 'красноперка', 'налим', 'густера',
         'амур', 'сазан', 'подуст', 'толстолобик', 'вобла', 'хариус']
fishs_cic = ['щука', 'судак', 'окунь', 'берш', 'речная форель', 'озерная форель', 'жерех']

# %%
fish_rec = {
    'щука': {
        1: {15: 0.35, 31: 0.4},
        2: {15: 0.45, 31: 0.57},
        3: {20: 0.65, 31: 0.75},
        4: {15: 0.25, 31: 0.7},
        5: {31: 0.6},
        6: {15: 0.5, 31: 0.39},
        7: {31: 0.35},
        8: {15: 0.38, 31: 0.4},
        9: {15: 0.5, 31: 0.55},
        10: {15: 0.65, 31: 0.6},
        11: {31: 0.5},
        12: {15: 0.4, 31: 0.35},
    },
    'судак': {
        1: {31: 0.4},
        2: {31: 0.45},
        3: {15: 0.55, 31: 0.65},
        4: {15: 0.7, 31: 0.35},
        5: {15: 0.3, 31: 0.5},
        6: {31: 0.6},
        7: {15: 0.65, 31: 0.6},
        8: {15: 0.45, 31: 0.4},
        9: {31: 0.6},
        10: {31: 0.65},
        11: {15: 0.5, 31: 0.4},
        12: {31: 0.35},
    },
    'окунь': {
        1: {31: 0.4},
        2: {31: 0.55},
        3: {31: 0.5},
        4: {15: 0.4, 31: 0.3},
        5: {15: 0.35, 31: 0.7},
        6: {31: 0.65},
        7: {31: 0.67},
        8: {31: 0.7},
        9: {31: 0.65},
        10: {31: 0.55},
        11: {31: 0.4},
        12: {31: 0.3},
    },
    'берш': {
        1: {31: 0.3},
        2: {31: 0.4},
        3: {31: 0.5},
        4: {15: 0.5, 31: 0.3},
        5: {15: 0.3, 31: 0.35},
        6: {15: 0.7, 31: 0.65},
        7: {31: 0.65},
        8: {15: 0.6, 31: 0.55},
        9: {31: 0.5},
        10: {15: 0.4, 31: 0.5},
        11: {31: 0.3},
        12: {31: 0.35},
    },
    'речная форель': {
        1: {15: 0.3, 31: 0.5},
        2: {31: 0.7},
        3: {15: 0.65, 31: 0.7},
        4: {15: 0.7, 31: 0.65},
        5: {15: 0.6, 31: 0.65},
        6: {15: 0.7, 31: 0.6},
        7: {15: 0.65, 31: 0.7},
        8: {15: 0.65, 31: 0.6},
        9: {15: 0.55, 31: 0.5},
        10: {15: 0.45, 31: 0.35},
        11: {15: 0.35, 31: 0.3},
        12: {15: 0.25, 31: 0.45},
    },
    'озерная форель': {
        1: {31: 0.6},
        10: {15: 0.4, 31: 0.35},
        11: {15: 0.3, 31: 0.25},
        12: {15: 0.2, 31: 0.2},
    },
    'подуст': {
        1: {15: 0.2, 31: 0.25},
        2: {15: 0.2, 31: 0.25},
        3: {15: 0.2, 31: 0.35},
        4: {15: 0.5, 31: 0.3},
        5: {15: 0.4, 31: 0.65},
        6: {15: 0.7, 31: 0.75},
        7: {15: 0.7, 31: 0.65},
        8: {15: 0.64, 31: 0.55},
        9: {15: 0.5, 31: 0.45},
        10: {15: 0.4, 31: 0.3},
        11: {15: 0.25, 31: 0.25},
        12: {15: 0.2, 31: 0.2},
    },
    'толстолобик': {
        1: {15: 0.2, 31: 0.2},
        2: {15: 0.2, 31: 0.2},
        3: {15: 0.2, 31: 0.25},
        4: {15: 0.3, 31: 0.35},
        5: {15: 0.45, 31: 0.5},
        6: {15: 0.6, 31: 0.65},
        7: {15: 0.7, 31: 0.6},
        8: {15: 0.55, 31: 0.5},
        9: {15: 0.4, 31: 0.35},
        10: {15: 0.25, 31: 0.2},
        11: {15: 0.2, 31: 0.2},
        12: {15: 0.2, 31: 0.2},
    },
    'вобла': {
        1: {15: 0.2, 31: 0.25},
        2: {15: 0.2, 31: 0.25},
        3: {15: 0.25, 31: 0.3},
        4: {15: 0.5, 31: 0.35},
        5: {15: 0.4, 31: 0.65},
        6: {15: 0.7, 31: 0.65},
        7: {15: 0.55, 31: 0.65},
        8: {15: 0.55, 31: 0.45},
        9: {15: 0.4, 31: 0.35},
        10: {15: 0.3, 31: 0.25},
        11: {15: 0.25, 31: 0.2},
        12: {15: 0.2, 31: 0.2},
    },
    'хариус':{
        1: {15: 0.3, 31: 0.3},
        2: {15: 0.35, 31: 0.4},
        3: {15: 0.45, 31: 0.5},
        4: {15: 0.55, 31: 0.6},
        5: {15: 0.65, 31: 0.3},
        6: {15: 0.35, 31: 0.7},
        7: {15: 0.55, 31: 0.6},
        8: {15: 0.7, 31: 0.55},
        9: {15: 0.5, 31: 0.45},
        10: {15: 0.4, 31: 0.35},
        11: {15: 0.3, 31: 0.25},
        12: {15: 0.25, 31: 0.35},
    }
}

# %%
obl_map = {
    'suncl': 'облачно',
    'sunc': 'малооблачно',
    'dull': 'пасмурно',
    'sun': 'ясно',
    '-': '-'
}
phen_map = {
    'snow': 'снег',
    'rain': 'дождь',
    'storm': 'шторм',
    '-': '-'
}
month_map = {
    1: 'январь',
    2: 'февраль',
    3: 'март',
    4: 'апрель',
    5: 'май',
    6: 'июнь',
    7: 'июль',
    8: 'август',
    9: 'сентябрь',
    11: 'ноябрь',
    12: 'декабрь',
    10: 'октябрь',
}

# %%
moon_intervals = {
    -1: {
        (0.8, 1.0): -1,
        (-0.001, 0.07): -1,
        (0.2, 0.5): -1,
        (0.5, 0.8): 0,
        (0.07, 0.2): 0,
    },
    1: {
        (-0.001, 0.2): -1,
        (0.95, 1.0): -1,
        (0.5, 0.75): 1,
        (0.2, 0.5): 0,
        (0.75, 0.95): 0,
    },
    0: {
        (-0.001, 0.2): -1,
        (0.95, 1.0): -1,
        (0.5, 0.75): 1,
        (0.2, 0.5): 0,
        (0.75, 0.95): 0,
    }
}

def stage_flag(moon_direction, moon):
    for left_right in moon_intervals[moon_direction]:
        if moon / 100 > left_right[0] and moon / 100 <= left_right[1]:
            return moon_intervals[moon_direction][left_right]

def gen_moon(days):
    moon = randint(0, 99)
    moon_dir = randint(0, 1)
    moons, moon_dirs = [], []
    for _ in range(days):
        if moon_dir:
            moon += 7
            if moon > 100:
                moon = 200 - moon
                moon_dir = 0
        else:
            moon -= 7
            if moon < 0:
                moon = -moon
                moon_dir = 1
        moons.append(moon)
        moon_dirs.append(moon_dir)
    return moons, moon_dirs

def moon_forecast(moon, moon_dir):
    forecast = []
    for moon_, dir_ in zip(moon, moon_dir):
        forecast.append(stage_flag(dir_, moon_))
    return forecast
 
def wind_forecast(fish, winds, wind_dirs):
    forecast = []
    for wind, wind_dir in zip(winds, wind_dirs):  
        if fish == 'окунь':
            forecast.append(int(wind <= 3))
            continue
        if wind_dir in ['В', 'СВ', 'С']:
            forecast.append(-1 + int(wind <= 2))
        elif wind_dir in ['СЗ', 'ЮВ']:
            if wind <= 1:
                forecast.append(1)
            elif wind <= 3:
                forecast.append(0)
            else:
                forecast.append(-1)
        else:
            if wind <= 4:
                forecast.append(1)
            else:
                forecast.append(0)
    return forecast

def temp_forecast(fish, temps, obls, phens):
    forecast = []
    for temp, obl, phen in zip(temps, obls, phens):
        if fish in fishs_bel:
            if obl == 'dull':
                if phen == '-':
                    forecast.append(0)
                else:
                    forecast.append(-1)
            else:
                if phen == 'rain':
                    forecast.append(0)
                elif phen == '-':
                    forecast.append(1)
                else:
                    forecast.append(-1)
        else:
            if obl == 'dull':
                if phen == 'storm':
                    forecast.append(-1)
                else:
                    forecast.append(1)
            else:
                forecast.append(0)
    return forecast

def pressure_forecast(pressure):
    forecast = [0, 0, 0]
    for i in range(3, len(pressure)):
        subs = [pressure[i] - pressure[i - 1], pressure[i - 1] - pressure[i- 2], pressure[i - 2] - pressure[i - 3]]
        sum_ = abs(pressure[i] - pressure[i - 3])
        if sum_ > 10:
            forecast.append(-1)
            continue
        sum_ = sum(map(abs, subs))
        if sum_  < 6:
            forecast.append(1)
            continue
        sum_ = sum(map(abs, subs[:-1]))
        if sum_  < 4:
            forecast.append(1)
            continue
        sum_ = sum(map(abs, subs[:-2]))
        forecast.append(-1 + int(sum_ < 2))
    return forecast

def time_forecast(fish, months, days):
    forecast = []
    for month, day in zip(months, days):
        temp = fish_rec[fish][month]
        temp = {key: temp[key] for key in sorted(temp.keys())}
        for key in temp:
            if day <= key:
                forecast.append(temp[key])
                break
    return forecast

# %%
dt = pd.read_csv('forecast1.csv', sep=';')
cols = ['day_temp', 'day_pressure', 'day_obl', 'day_phen', 'day_dir', 'day_wind', 'areal', 'city', 'year', 'month', 'day']
fishs_dt = [dt[cols + [fish]] for fish in fishs]
for i in range(len(fishs)):
    fish = fishs[i]
    fishs_dt[i]['pressure_forecast'] = pressure_forecast(list(fishs_dt[i]['day_pressure']))
    fishs_dt[i]['pressure_forecast'] = (1 + fishs_dt[i]['pressure_forecast']) / 2
    fishs_dt[i]['temp_forecast'] = temp_forecast(fish, list(fishs_dt[i]['day_temp']), list(fishs_dt[i]['day_obl']), list(fishs_dt[i]['day_phen']))
    fishs_dt[i]['temp_forecast'] = (1 + fishs_dt[i]['temp_forecast']) / 2
    fishs_dt[i]['wind_forecast'] = wind_forecast(fish, list(fishs_dt[i]['day_wind']), list(fishs_dt[i]['day_dir']))
    fishs_dt[i]['wind_forecast'] = (1 + fishs_dt[i]['wind_forecast']) / 2
    moon, moon_dir = gen_moon(len(fishs_dt[i]))
    fishs_dt[i]['moon_forecast'] = moon_forecast(moon, moon_dir)
    fishs_dt[i]['moon_forecast'] = (1 + fishs_dt[i]['moon_forecast']) / 2
    fishs_dt[i]['time_forecast'] = time_forecast(fish, list(fishs_dt[i]['month']), list(fishs_dt[i]['day']))
    fishs_dt[i]['forecast'] = (fishs_dt[i]['pressure_forecast'] + fishs_dt[i]['temp_forecast'] + fishs_dt[i]['wind_forecast'] + fishs_dt[i]['moon_forecast']) / 4 * fishs_dt[i]['time_forecast']
    fishs_dt[i]['forecast'] = fishs_dt[i]['forecast']  * (0.5 / fishs_dt[i]['forecast'].mean())
    fishs_dt[i]['forecast'] = fishs_dt[i]['forecast'].apply(lambda x: int(x > 0.5))
# Out:
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fishs_dt[0].describe()
# Out:
#            day_temp  day_pressure      day_wind     year         month  \
# count  30521.000000  30521.000000  30521.000000  30521.0  30521.000000
# mean       9.887618    740.352806      3.155041   2020.0      6.522427
# std       12.342970     31.776627      2.051422      0.0      3.447542
# min      -43.000000    565.000000      0.000000   2020.0      1.000000
# 25%        1.000000    739.000000      2.000000   2020.0      4.000000
# 50%       10.000000    748.000000      3.000000   2020.0      7.000000
# 75%       20.000000    755.000000      4.000000   2020.0     10.000000
# max       41.000000    785.000000     44.000000   2020.0     12.000000
#
#                 day          щука  pressure_forecast  temp_forecast  \
# count  30521.000000  30521.000000       30521.000000   30521.000000
# mean      15.766751     -0.994627           0.348334       0.683005
# std        8.807696      0.096654           0.453649       0.248790
# min        1.000000     -1.000000           0.000000       0.000000
# 25%        8.000000     -1.000000           0.000000       0.500000
# 50%       16.000000     -1.000000           0.000000       0.500000
# 75%       23.000000     -1.000000           1.000000       1.000000
# max       31.000000      1.000000           1.000000       1.000000
#
#        wind_forecast  moon_forecast  time_forecast      forecast
# count   30521.000000   30521.000000   30521.000000  30521.000000
# mean        0.602044       0.500049       0.487810      0.444972
# std         0.394525       0.353565       0.126325      0.496971
# min         0.000000       0.000000       0.250000      0.000000
# 25%         0.500000       0.500000       0.380000      0.000000
# 50%         0.500000       0.500000       0.500000      0.000000
# 75%         1.000000       1.000000       0.600000      1.000000
# max         1.000000       1.000000       0.750000      1.000000

# %%
idx = randint(10, len(fishs_dt[0]))
fishs_dt[0][idx - 10: idx]
# Out:
#       day_temp  day_pressure day_obl day_phen day_dir  day_wind  \
# 9888        20           743   suncl        -      ЮЗ         3
# 9889        19           745    dull        -      ЮЗ         3
# 9890        13           747    dull        -       С         1
# 9891        16           746   suncl        -       З         3
# 9892        11           745    dull        -       З         2
# 9893        20           747    dull        -      СЗ         2
# 9894        24           743   suncl        -      ЮЗ         5
# 9895        13           750    sunc        -      СЗ         4
# 9896        15           752    dull        -       Ю         4
# 9897        15           749    dull        -      СЗ         1
#
#                     areal   city  year  month  day  щука  pressure_forecast  \
# 9888  Воронежская область  Лиски  2020      5    6    -1                0.0
# 9889  Воронежская область  Лиски  2020      5    7    -1                0.0
# 9890  Воронежская область  Лиски  2020      5    8    -1                0.0
# 9891  Воронежская область  Лиски  2020      5    9    -1                1.0
# 9892  Воронежская область  Лиски  2020      5   10    -1                1.0
# 9893  Воронежская область  Лиски  2020      5   11    -1                1.0
# 9894  Воронежская область  Лиски  2020      5   12    -1                0.0
# 9895  Воронежская область  Лиски  2020      5   13    -1                0.0
# 9896  Воронежская область  Лиски  2020      5   14    -1                0.0
# 9897  Воронежская область  Лиски  2020      5   15    -1                0.0
#
#       temp_forecast  wind_forecast  moon_forecast  time_forecast  forecast
# 9888            0.5            1.0            1.0            0.6         1
# 9889            1.0            1.0            0.5            0.6         1
# 9890            1.0            0.5            0.5            0.6         1
# 9891            0.5            1.0            0.5            0.6         1
# 9892            1.0            1.0            0.5            0.6         1
# 9893            1.0            0.5            0.0            0.6         1
# 9894            0.5            0.5            0.0            0.6         0
# 9895            0.5            0.0            0.0            0.6         0
# 9896            1.0            1.0            0.0            0.6         1
# 9897            1.0            1.0            0.0            0.6         1

# %%
from sklearn.metrics import accuracy_score

for i in range(len(fishs_dt)):
    fish = fishs[i]
    temp_dt = fishs_dt[i][fishs_dt[i][fish] > -1]
    print('Fish: {}, Accuracy: {}'.format(fish, accuracy_score(temp_dt[fish], temp_dt['forecast'])))
#     print()
# Out:
# Fish: щука, Accuracy: 0.6407766990291263
# Fish: судак, Accuracy: 0.7475728155339806
# Fish: окунь, Accuracy: 0.6310679611650486
# Fish: берш, Accuracy: 0.6601941747572816
# Fish: речная форель, Accuracy: 0.7184466019417476
# Fish: озерная форель, Accuracy: 0.8155339805825242
# Fish: елец, Accuracy: 0.8446601941747572
# Fish: чехонь, Accuracy: 0.7864077669902912
# Fish: сом, Accuracy: 0.8349514563106796
# Fish: голавль, Accuracy: 0.7669902912621359
# Fish: язь, Accuracy: 0.7766990291262136
# Fish: карп, Accuracy: 0.8252427184466019
# Fish: жерех, Accuracy: 0.8252427184466019
# Fish: лещ, Accuracy: 0.6796116504854369
# Fish: карась, Accuracy: 0.8155339805825242
# Fish: линь, Accuracy: 0.8349514563106796
# Fish: пескарь, Accuracy: 0.7281553398058253
# Fish: ротан, Accuracy: 0.7087378640776699
# Fish: плотва, Accuracy: 0.7475728155339806
# Fish: красноперка, Accuracy: 0.7281553398058253
# Fish: налим, Accuracy: 0.7766990291262136
# Fish: густера, Accuracy: 0.6601941747572816
# Fish: амур, Accuracy: 0.7961165048543689
# Fish: ерш, Accuracy: 0.5436893203883495
# Fish: сазан, Accuracy: 0.7475728155339806
# Fish: подуст, Accuracy: 0.8252427184466019
# Fish: толстолобик, Accuracy: 0.7378640776699029
# Fish: вобла, Accuracy: 0.6601941747572816
# Fish: хариус, Accuracy: 0.6310679611650486

# %%
import matplotlib.pyplot as plt

fishs_dt[5]['forecast'][:365].plot()

# %%
cols = ['day_temp', 'day_pressure', 'day_obl', 'day_phen', 'day_dir', 'day_wind', 'areal', 'city', 'year', 'month', 'day', 'forecast']
result_dt = fishs_dt[0][cols]
result_dt = result_dt.rename({'forecast': 'Щука'}, axis=1)
for i in range(1, len(fishs)):
    fish = fishs[i].capitalize()
    result_dt[fish] = fishs_dt[i]['forecast']

# %%
result_dt.describe()
# Out:
#            day_temp  day_pressure      day_wind     year         month  \
# count  30521.000000  30521.000000  30521.000000  30521.0  30521.000000
# mean       9.887618    740.352806      3.155041   2020.0      6.522427
# std       12.342970     31.776627      2.051422      0.0      3.447542
# min      -43.000000    565.000000      0.000000   2020.0      1.000000
# 25%        1.000000    739.000000      2.000000   2020.0      4.000000
# 50%       10.000000    748.000000      3.000000   2020.0      7.000000
# 75%       20.000000    755.000000      4.000000   2020.0     10.000000
# max       41.000000    785.000000     44.000000   2020.0     12.000000
#
#                 day          Щука         Судак         Окунь          Берш  \
# count  30521.000000  30521.000000  30521.000000  30521.000000  30521.000000
# mean      15.766751      0.444972      0.444907      0.451984      0.472822
# std        8.807696      0.496971      0.496964      0.497697      0.499269
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%        8.000000      0.000000      0.000000      0.000000      0.000000
# 50%       16.000000      0.000000      0.000000      0.000000      0.000000
# 75%       23.000000      1.000000      1.000000      1.000000      1.000000
# max       31.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...   Красноперка         Налим       Густера          Амур  \
# count  ...  30521.000000  30521.000000  30521.000000  30521.000000
# mean   ...      0.442122      0.404836      0.497526      0.381508
# std    ...      0.496647      0.490868      0.500002      0.485765
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      1.000000      1.000000      1.000000      1.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#                 Ерш         Сазан        Подуст   Толстолобик         Вобла  \
# count  30521.000000  30521.000000  30521.000000  30521.000000  30521.000000
# mean       0.523869      0.422562      0.401035      0.373546      0.391239
# std        0.499438      0.493975      0.490116      0.483753      0.488036
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              Хариус
# count  30521.000000
# mean       0.442024
# std        0.496635
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 35 columns]

# %%
result_dt.to_csv('forecast2.csv', sep=';', index=False)
