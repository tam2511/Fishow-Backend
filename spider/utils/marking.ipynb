# %%
import pandas as pd
from IPython.display import clear_output
from random import choice, randint

# %%
fishs = ['щука', 'судак', 'окунь', 'берш', 'речная форель', 'озерная форель', 'елец', 'чехонь', 'сом', 'голавль', 'язь',
         'карп', 'жерех', 'лещ', 'карась', 'линь', 'пескарь', 'ротан', 'плотва', 'красноперка', 'налим', 'густера',
         'амур', 'ерш', 'сазан', 'подуст', 'толстолобик', 'вобла', 'хариус']

# %%
fish_rec = {
    'щука': {
        1: 'Слабый клев',
        2: 'Слабый клев, но лучше чем в феврале',
        3: 'Жор. Особенно в теплую погоду (начинается нерест)',
        4: 'Отличный клев, но более после нереста',
        5: 'Хороший клев',
        6: 'В начале месяца - хороший, в конце - средний',
        7: 'Средний клев',
        8: 'В начале - средний, в конце - хороший клев',
        9: 'Хороший клев, в конце - отличный',
        10: 'Отличный клев',
        11: 'Средний клев, хорошо в плохую погоду',
        12: 'Хороший клев',
    },
    'судак': {
        1: 'Средний клев',
        2: 'Средний клев, но лучше в оттепель и снегопад',
        3: 'Средний клев,но в конце наиболее активно',
        4: 'Хороший клев, но в конце уходит на нерест',
        5: 'Рыба болеет после нереста',
        6: 'Отличный клев',
        7: 'Отличный клев, но с жарой клев падает',
        8: 'Вначале средне, в конце - хорошо',
        9: 'Отличный клев',
        10: 'Отличный клев',
        11: 'Средний клев, при заморозках - плохо',
        12: 'Плохой клев',
    },
    'окунь': {
        1: 'Средний клев',
        2: 'Хороший клев',
        3: 'Хороший клев в начале, средний - в конце',
        4: 'Средний в начале, нерест - в конце',
        5: 'В начале - плохо, в конце - хорошо',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Отличный',
        9: 'Отличный клев',
        10: 'Хороший клев, но не в пасмурную',
        11: 'Плохой клев',
        12: 'Средний клев',
    },
    'берш': {
        1: 'Средний клев',
        2: 'Средний клев',
        3: 'Хороший клев',
        4: 'Средний',
        5: 'Плохо, нерест',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший в начале, средний в конце',
        9: 'Средний клев',
        10: 'Хороший клев',
        11: 'Плохой клев',
        12: 'Средний клев',
    },
    'речная форель': {
        1: 'Средний клев',
        2: 'Отличный клев',
        3: 'Хороший клев',
        4: 'Отличный клев',
        5: 'Отличный клев',
        6: 'Отличный клев',
        7: 'Отличный клев',
        8: 'Отличный клев',
        9: 'Хороший клев в начале, в конце - нерест',
        10: 'Нерест',
        11: 'Плохой клев, в конце средний',
        12: 'Средний клев',
    },
    'озерная форель': {
        1: 'Средний клев',
        2: 'Отличный клев',
        3: 'Хороший клев',
        4: 'Средний клев',
        5: 'Слабый клев',
        6: 'Слабый клев',
        7: 'Слабый клев',
        8: 'Слабый клев',
        9: 'Слабый клев',
        10: 'Средний клев',
        11: 'Средний клев',
        12: 'Средний клев',
    },
    'елец': {
        1: 'Слабый клев',
        2: 'Слабый клев',
        3: 'Слабый клев',
        4: 'Средний клев',
        5: 'Средний клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Слабый клев',
        12: 'Слабый клев',
    },
    'чехонь': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Средний клев',
        5: 'В начале - нерест, в конце - отличный клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев',
        10: 'Средний клев в хорошую погоду, иначе - слабый',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'сом': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев',
        5: 'Нерест',
        6: 'Хороший клев',
        7: 'Отличный клев',
        8: 'Отличный клев',
        9: 'Средний клев',
        10: 'Слабый клев',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'голавль': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Средний клева',
        4: 'Вначале хороший, в конце - нерест',
        5: 'Отличный клев',
        6: 'Отличный клев',
        7: 'Хороший клев',
        8: 'Отличный клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Слабый клева',
        12: 'Нету клева',
    },
    'язь': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Слабый клев',
        4: 'Средний клев, в конце - нерест',
        5: 'Хороший клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Отличный клев',
        9: 'Отличный клев',
        10: 'Средний клев',
        11: 'Вначале средний, в конце - слабый',
        12: 'Нету клева',
    },
    'карп': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев, в конце - может повезти',
        5: 'Средний клев в теплые дни, в остальном - плохо',
        6: 'В начале - средний, в конце - хороший (нерест)',
        7: 'Отличный клев',
        8: 'Отличный клев',
        9: 'Средний клев',
        10: 'Плохой клев',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'жерех': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев, в конце - нерест',
        5: 'Отличный клев',
        6: 'Отличный клев',
        7: 'Хороший клев',
        8: 'Отличный клев',
        9: 'Хороший клев',
        10: 'Средний клев в начале и плохой в конце',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'лещ': {
        1: 'Слабый клева',
        2: 'Средний клева',
        3: 'Хороший клева',
        4: 'Хороший клев, в конце - нерест',
        5: 'В начале нерест, в конце - отлично',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'В начале слабый, в конце - нету клева',
        12: 'Нету клева',
    },
    'карась': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев, в конце - нерест',
        5: 'Средний клев в теплые дни, в остальном - плохо',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев, хороший в теплые дни',
        10: 'Слабый клев',
        11: 'Нету клева',
        12: 'Нету клева',
    },  
    'линь': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев',
        5: 'Средний клев в теплые дни, в остальном - плохо',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев, хороший в теплые дни',
        10: 'Слабый клев',
        11: 'Нету клева',
        12: 'Нету клева',
    }, 
    'пескарь': {
        1: 'Нету клева',
        2: 'Слабый в оттепель',
        3: 'Средний клева',
        4: 'Средний клев',
        5: 'Хороший клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев',
        10: 'Слабый клев',
        11: 'Нету клева',
        12: 'Нету клева',
    }, 
    'ротан': {
        1: 'Слабый клев',
        2: 'Средний клев',
        3: 'Хороший клева',
        4: 'Хороший клев',
        5: 'Хороший клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Слабый клева',
        12: 'Средний клева',
    }, 
    'плотва': {
        1: 'Слабый клев',
        2: 'Средний клев',
        3: 'Хороший клева',
        4: 'В начале - нерест, в конце - хороший клев',
        5: 'Хороший клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Слабый клева',
        12: 'Клева нет',
    },
    'красноперка': {
        1: 'Слабый клев',
        2: 'Средний клев',
        3: 'Хороший клева',
        4: 'В начале - хороший, в конце - нерест',
        5: 'Хороший клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Клева нет',
        12: 'Клева нет',
    },
    'налим': {
        1: 'Хороший клев',
        2: 'Хороший клев',
        3: 'Хороший клев',
        4: 'Средний клев',
        5: 'Слабый клев',
        6: 'Клева нет',
        7: 'Клева нет',
        8: 'Клева нет',
        9: 'Клева нет',
        10: 'Средний клев',
        11: 'Хороший клев',
        12: 'Хороший клев',
    },
    'густера': {
        1: 'Средний клев',
        2: 'Средний клев',
        3: 'Средний клев',
        4: 'Хороший клев',
        5: 'В начале - нерест, потом - хороший',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Слабый клев',
        12: 'Слабый клев',
    },
    'амур': {
        1: 'Клева нет',
        2: 'Клева нет',
        3: 'Клева нет',
        4: 'Клева нет',
        5: 'Клева есть если тепло',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Слабый клев',
        11: 'Клева нет',
        12: 'Клева нет',
    },
    'ерш': {
        1: 'Хороший клев',
        2: 'Хороший клев',
        3: 'Хороший клев',
        4: 'Хороший клев',
        5: 'Хороший клев, в начале - нерест',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Хороший клев',
        11: 'Хороший клев',
        12: 'Хороший клев',
    },
    'сазан': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Нету клева',
        5: 'Слабый клев, нерест',
        6: 'Слабый клев, в конце - хороший',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев',
        10: 'Плохой клев',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'подуст': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Нету клева',
        5: 'Средний клев в конце',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев',
        10: 'Клева нет',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'толстолобик': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Слабый клев',
        5: 'Средний клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Средний клев',
        9: 'Средний клев',
        10: 'Средний клев',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'вобла': {
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Средний клев',
        5: 'Хороший клев, в конце - нерест',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Средний клев',
        10: 'Нету клева',
        11: 'Нету клева',
        12: 'Нету клева',
    },
    'хариус':{
        1: 'Нету клева',
        2: 'Нету клева',
        3: 'Нету клева',
        4: 'Нету клева',
        5: 'Отличный клев',
        6: 'Хороший клев',
        7: 'Хороший клев',
        8: 'Хороший клев',
        9: 'Хороший клев',
        10: 'Средний клев',
        11: 'Нету клева',
        12: 'Нету клева',
    }
}

# %%
obl_map = {
    'suncl': 'облачно',
    'sunc': 'малооблачно',
    'dull': 'пасмурно',
    'sun': 'ясно',
    '-': '-'
}
phen_map = {
    'snow': 'снег',
    'rain': 'дождь',
    'storm': 'шторм',
    '-': '-'
}
month_map = {
    1: 'январь',
    2: 'февраль',
    3: 'март',
    4: 'апрель',
    5: 'май',
    6: 'июнь',
    7: 'июль',
    8: 'август',
    9: 'сентябрь',
    11: 'ноябрь',
    12: 'декабрь',
    10: 'октябрь',
}

# %%
dt = pd.read_csv('forecast1.csv', sep=';')

result = []
while True:
    clear_output(wait=True)
    idx = randint(0, len(dt) - 1)
    dts = dt[idx - 3: idx + 1]
    if dt.loc[idx, fishs[0]] > -1:
        continue
    dict_values = dts.T.to_dict()
    indexes = dts.index.to_list()
    print('Область: {}'.format(dt.loc[idx, 'areal']))
    print('Город: {}'.format(dt.loc[idx, 'city']))
    print('Месяц:      \t{}\t{}\t{}\t{}'.format(*[month_map[dict_values[index]['month']] for index in indexes]))
    print('День:      \t{}\t{}\t{}\t{}'.format(*[dict_values[index]['day'] for index in indexes]))
    print('Температура:\t{}\t{}\t{}\t{}'.format(*[dict_values[index]['day_temp'] for index in indexes]))
    print('Давление:\t{}\t{}\t{}\t{}'.format(*[dict_values[index]['day_pressure'] for index in indexes]))
    print('Облачность:\t{}\t{}\t{}\t{}'.format(*[obl_map[dict_values[index]['day_obl']] for index in indexes]))
    print('Явление:\t{}\t{}\t{}\t{}'.format(*[phen_map[dict_values[index]['day_phen']] for index in indexes]))
    print('Направление:\t{}\t{}\t{}\t{}'.format(*[dict_values[index]['day_dir'] for index in indexes]))
    print('Ветер:        \t{}\t{}\t{}\t{}'.format(*[dict_values[index]['day_wind'] for index in indexes]))
    for fish in fishs:
        print('{} ({}):'.format(fish, fish_rec[fish][dict_values[indexes[-1]]['month']]), end='')
        forecast = input()
        dt.loc[idx, fish] = forecast
# Out:
# Область: Московская область
# Город: Дубна
# Месяц:      	ноябрь	ноябрь	ноябрь	ноябрь
# День:      	7	8	9	10
# Температура:	10	8	2	4
# Давление:	752	747	755	758
# Облачность:	-	-	-	-
# Явление:	-	-	-	-
# Направление:	СЗ	СЗ	ЮЗ	З
# Ветер:        	4	2	3	3
# щука (Средний клев, хорошо в плохую погоду):1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ...

# %%
dt.to_csv('forecast1.csv', index=False, sep=';')

# %%
dt = pd.read_csv('forecast1.csv', sep=';')
dt[dt['щука'] > -1]
# Out:
#        day_temp  day_pressure day_obl day_phen day_dir  day_wind  \
# 142          17           751    dull    storm       З         1
# 143          23           752   suncl        -       З         1
# 144          22           751    dull        -      ЮЗ         1
# 152          25           740     sun        -       С         2
# 198          32           744    sunc        -      СВ         2
# ...         ...           ...     ...      ...     ...       ...
# 29138        10           745   suncl        -       Ю         3
# 29183        10           736     sun        -      СЗ         8
# 29278        26           746    dull        -       Ю         5
# 29651        25           749     sun        -      ЮЗ         3
# 29972        24           748       -        -      СЗ         3
#
#                     areal           city  year  month  ...  красноперка  \
# 142        Алтайский край        Барнаул  2020      5  ...            1
# ...
